# %%
import pandas as pd
df = pd.read_csv('debt.csv')

# %%
df.head()
df.dropna()
# Out:
#           DATE   GFDEBTN  Standard Deviation
# 4     1/1/1967    330947        6.076287e+03
# 5     4/1/1967    322893        5.864907e+03
# 6     7/1/1967    335896        5.160808e+03
# 7    10/1/1967    344663        8.124034e+03
# 8     1/1/1968    349473        1.061730e+04
# ..         ...       ...                 ...
# 215  10/1/2019  23201380        5.489600e+05
# 216   1/1/2020  23223813        5.952556e+05
# 217   4/1/2020  26477241        1.718665e+06
# 218   7/1/2020  26945391        2.023247e+06
# 219  10/1/2020  27747798        2.154043e+06
#
# [216 rows x 3 columns]

# %%
##plotting the data

# %%
df.plot(figsize=(10,10), x="DATE", y=["Standard Deviation","GFDEBTN"] ylabel="In 10 Millions", title = "SDEV and DEBT Over Time")
# Out:
#   File "<ipython-input-30-d3512340a129>", line 1
#     df.plot(figsize=(10,10), x="DATE", y=["Standard Deviation","GFDEBTN"] ylabel="In 10 Millions", title = "SDEV and DEBT Over Time")
#                                                                           ^
# SyntaxError: invalid syntax

# %%
df.plot(figsize=(10,10), x="DATE", y=["Standard Deviation"], ylabel="Standard Deviation in Millions", title = "SDEV of US DEBT from 1966 to 2020")
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='Standard Deviation in Millions'>
